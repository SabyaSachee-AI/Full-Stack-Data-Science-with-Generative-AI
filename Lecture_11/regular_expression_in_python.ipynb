# %%
print("hello")
# Out:
# hello

# %% [markdown]
# #Email extractor Using Reguler Expression

# %%
text =

# %%
emails =re.findall(pattern,text)
print(emails)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 emails =re.findall(pattern,text)
#       2 print(emails)
#
# NameError: name 're' is not defined
